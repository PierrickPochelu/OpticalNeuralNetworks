# %% [markdown]
# # Optical Neural Network with numpy/jax
#
# ![alt text](mzi_mesh.jpg "Mesh type used")

# %% [markdown]
# ## Trainable photonic circuit
# MZI, column of MZI, mesh, ...

# %%
import jax
from jax import numpy as np

random_seed=1

def MZI(X, teta):
    R = np.array([
      [np.cos(teta), -np.sin(teta)],
      [np.sin(teta), np.cos(teta)]
    ])
    out_vector=np.dot(R, X)
    return out_vector

def MZI_col(X, nb_mzi, W):
    # Column type: odd or even ?
    nb_pins=nb_mzi*2
    if nb_pins==len(X):
        start_pin_id=0
    elif nb_pins+2==len(X):
        start_pin_id=1
    else:
        raise ValueError("This mesh patern is not compatible with this input size and #MZIs")

    # pin them
    layer_outputs=[]
    if start_pin_id==1:
        layer_outputs.append(np.array([X[0]]))
    
    for ID in range(0, nb_mzi):
        # take input vector
        first_pin_pos=2*ID+start_pin_id
        second_pin_pos=first_pin_pos+1
        local_inp = X[first_pin_pos:second_pin_pos+1]
        # compute the output vector
        local_out=MZI(local_inp, W[ID])
        layer_outputs.append(local_out)
    
    if start_pin_id==1:
        layer_outputs.append(np.array([X[-1]]))
    
    Y=np.concatenate(layer_outputs)
    return Y

def onn(X, nb_mzis, weights):
    nb_layers=len(weights)

    def recusive_layer_builder(id_layer=0):
        if id_layer==nb_layers-1: # last layer. No dependency
            input_shape=X.shape
            y=MZI_col(X, nb_mzis[id_layer], weights[id_layer])
        else:
            y = recusive_layer_builder(id_layer + 1)
            input_shape=y.shape
            y=MZI_col(y, nb_mzis[id_layer], weights[id_layer])
        return y

    Y=recusive_layer_builder()
    return Y

def spec_mesh(cols, mzi_per_col): #e.g. 6,6->3,2,3,2,3,2
    cols=n_comp
    mzi_per_col=n_comp//2
    nb_mzis=[]
    for i in range(cols):
        nb_mzis.append( mzi_per_col-i%2 )
    return nb_mzis

def glorot_init(nb_mzi):
    key = jax.random.PRNGKey(random_seed)  # random seed is explicit
    weights=jax.random.normal(shape=(nb_mzi,), key=key,dtype=np.float32) * np.sqrt(0.5)
    return weights

# %% [markdown]
# ## Simple function learning: [0,1,0,1] -> [1,0,1,0]
# Simple problem before solving harder problems

# %% [markdown]
# Configuration of the training dataset and ONN

# %%
X=np.array([1, 0, 1, 0])
Y=np.array([0, 1, 0, 1])
nb_MZIs=(2,1,2,1)
W=[]
for n in nb_MZIs:
    W.append(glorot_init(n))

# %% [markdown]
# Backward

# %%
def circuit(X, W):
    return onn(X, nb_MZIs, W)
    
# Create the circuit with metric
def circuit_to_opt(*args):
    y_=circuit(*args)
    loss=np.mean((Y-y_)**2)
    return loss

deriv_circuit_to_opt=jax.grad(circuit_to_opt, argnums=(-1,))

# %% [markdown]
# Training loop

# %%
lr=0.5
print("First pred.:", circuit(X,W))
for i in range(10):
    
    # forward phase
    print("current loss:", circuit_to_opt(X,W))

    # backward phase
    dW=deriv_circuit_to_opt(X,W)[0]

    # Update using the gradient information
    for i, dWi in enumerate(dW):
        W[i] = W[i] - lr * dWi
print("Final pred.:", circuit(X,W))
# Out:
# First pred.: [0.03837496 1.0827922  0.01405865 0.90878546]
# current loss: 0.0042112293
# current loss: 0.0031466344
# current loss: 0.002370951
# current loss: 0.0017973367
# current loss: 0.0013688633
# current loss: 0.0010464268
# current loss: 0.000802356
# current loss: 0.0006167479
# current loss: 0.00047505228
# current loss: 0.00036653606
# Final pred.: [0.00749612 1.0225742  0.00562081 0.9768595 ]

# %% [markdown]
# Generate Python code of the backward Jax representation

# %%
import sys
import os
sys.path.append("/home/pierrick/PycharmProjects/JaxDecompiler/")
#for module_name in ["decompiler", "primitive_mapping"]:
#    os.remove(sys.modules[module_name].__cached__)  # remove cached bytecode
#    del sys.modules[module_name]
import decompiler # JaxDecompiler
df, c= decompiler.python_jaxpr_python(deriv_circuit_to_opt, (X, W), is_python_returned=True)
print(c)
# Out:
# import jax
# from jax.numpy import *
# def f(b, c, d, e, f):
#     a = Array([0, 1, 0, 1], dtype=int32)
#     g = b[0:0+(1,)[0]] # dynamic slice
#     h = squeeze(g)
#     i = array(broadcast_to(h, (1,)))
#     j = b[1:1+(2,)[0]] # dynamic slice
#     k = f[0:0+(1,)[0]] # dynamic slice
#     l = squeeze(k)
#     m = cos(l)
#     n = sin(l)
#     o = sin(l)
#     p = cos(l)
#     q = -o
#     r = sin(l)
#     s = cos(l)
#     t = cos(l)
#     u = sin(l)
#     v = array(broadcast_to(m, (1,)))
#     w = array(broadcast_to(q, (1,)))
#     x = concatenate((v, w), axis=0)
#     y = array(broadcast_to(r, (1,)))
#     z = array(broadcast_to(t, (1,)))
#     ba = concatenate((y, z), axis=0)
#     bb = array(broadcast_to(x, (1, 2)))
#     bc = array(broadcast_to(ba, (1, 2)))
#     bd = concatenate((bb, bc), axis=0)
#     be = array(j).astype(float32)
#     bf = dot(bd, be)
#     bg = -1 + 4
#     bh = array(bg).astype(int32)
#     bi = array(broadcast_to(bh, (1,)))
#     bj = squeeze( b[bi[0] if len(bi)>0 else 0:bi[0]+1] , axis=(0,))
#     bk = array(broadcast_to(bj, (1,)))
#     bl = array(i).astype(float32)
#     bm = array(bk).astype(float32)
#     bn = concatenate((bl, bf, bm), axis=0)
#     _ = array(broadcast_to(0.0, (1,)))
#     _ = array(broadcast_to(0.0, (1,)))
#     bo = bn[0:0+(2,)[0]] # dynamic slice
#     bp = e[0:0+(1,)[0]] # dynamic slice
#     bq = squeeze(bp)
#     br = cos(bq)
#     bs = sin(bq)
#     bt = sin(bq)
#     bu = cos(bq)
#     bv = -bt
#     bw = sin(bq)
#     bx = cos(bq)
#     by = cos(bq)
#     bz = sin(bq)
#     ca = array(broadcast_to(br, (1,)))
#     cb = array(broadcast_to(bv, (1,)))
#     cc = concatenate((ca, cb), axis=0)
#     cd = array(broadcast_to(bw, (1,)))
#     ce = array(broadcast_to(by, (1,)))
#     cf = concatenate((cd, ce), axis=0)
#     cg = array(broadcast_to(cc, (1, 2)))
#     ch = array(broadcast_to(cf, (1, 2)))
#     ci = concatenate((cg, ch), axis=0)
#     cj = dot(ci, bo)
#     ck = bn[2:2+(2,)[0]] # dynamic slice
#     cl = e[1:1+(1,)[0]] # dynamic slice
#     cm = squeeze(cl)
#     cn = cos(cm)
#     co = sin(cm)
#     cp = sin(cm)
#     cq = cos(cm)
#     cr = -cp
#     cs = sin(cm)
#     ct = cos(cm)
#     cu = cos(cm)
#     cv = sin(cm)
#     cw = array(broadcast_to(cn, (1,)))
#     cx = array(broadcast_to(cr, (1,)))
#     cy = concatenate((cw, cx), axis=0)
#     cz = array(broadcast_to(cs, (1,)))
#     da = array(broadcast_to(cu, (1,)))
#     db = concatenate((cz, da), axis=0)
#     dc = array(broadcast_to(cy, (1, 2)))
#     dd = array(broadcast_to(db, (1, 2)))
#     de = concatenate((dc, dd), axis=0)
#     df = dot(de, ck)
#     dg = concatenate((cj, df), axis=0)
#     dh = dg[0:0+(1,)[0]] # dynamic slice
#     di = squeeze(dh)
#     dj = array(broadcast_to(di, (1,)))
#     dk = dg[1:1+(2,)[0]] # dynamic slice
#     dl = d[0:0+(1,)[0]] # dynamic slice
#     dm = squeeze(dl)
#     dn = cos(dm)
#     do = sin(dm)
#     dp = sin(dm)
#     dq = cos(dm)
#     dr = -dp
#     ds = sin(dm)
#     dt = cos(dm)
#     du = cos(dm)
#     dv = sin(dm)
#     dw = array(broadcast_to(dn, (1,)))
#     dx = array(broadcast_to(dr, (1,)))
#     dy = concatenate((dw, dx), axis=0)
#     dz = array(broadcast_to(ds, (1,)))
#     ea = array(broadcast_to(du, (1,)))
#     eb = concatenate((dz, ea), axis=0)
#     ec = array(broadcast_to(dy, (1, 2)))
#     ed = array(broadcast_to(eb, (1, 2)))
#     ee = concatenate((ec, ed), axis=0)
#     ef = dot(ee, dk)
#     eg = -1 + 4
#     eh = array(eg).astype(int32)
#     ei = array(broadcast_to(eh, (1,)))
#     ej = squeeze( dg[ei[0] if len(ei)>0 else 0:ei[0]+1] , axis=(0,))
#     ek = array(broadcast_to(ej, (1,)))
#     el = concatenate((dj, ef, ek), axis=0)
#     em = el[0:0+(2,)[0]] # dynamic slice
#     en = c[0:0+(1,)[0]] # dynamic slice
#     eo = squeeze(en)
#     ep = cos(eo)
#     eq = sin(eo)
#     er = sin(eo)
#     es = cos(eo)
#     et = -er
#     eu = sin(eo)
#     ev = cos(eo)
#     ew = cos(eo)
#     ex = sin(eo)
#     ey = array(broadcast_to(ep, (1,)))
#     ez = array(broadcast_to(et, (1,)))
#     fa = concatenate((ey, ez), axis=0)
#     fb = array(broadcast_to(eu, (1,)))
#     fc = array(broadcast_to(ew, (1,)))
#     fd = concatenate((fb, fc), axis=0)
#     fe = array(broadcast_to(fa, (1, 2)))
#     ff = array(broadcast_to(fd, (1, 2)))
#     fg = concatenate((fe, ff), axis=0)
#     fh = dot(fg, em)
#     fi = el[2:2+(2,)[0]] # dynamic slice
#     fj = c[1:1+(1,)[0]] # dynamic slice
#     fk = squeeze(fj)
#     fl = cos(fk)
#     fm = sin(fk)
#     fn = sin(fk)
#     fo = cos(fk)
#     fp = -fn
#     fq = sin(fk)
#     fr = cos(fk)
#     fs = cos(fk)
#     ft = sin(fk)
#     fu = array(broadcast_to(fl, (1,)))
#     fv = array(broadcast_to(fp, (1,)))
#     fw = concatenate((fu, fv), axis=0)
#     fx = array(broadcast_to(fq, (1,)))
#     fy = array(broadcast_to(fs, (1,)))
#     fz = concatenate((fx, fy), axis=0)
#     ga = array(broadcast_to(fw, (1, 2)))
#     gb = array(broadcast_to(fz, (1, 2)))
#     gc = concatenate((ga, gb), axis=0)
#     gd = dot(gc, fi)
#     ge = concatenate((fh, gd), axis=0)
#     gf = array(a).astype(float32)
#     gg = gf - ge
#     gh = gg ** 2
#     gi = gg ** 1
#     gj = 2.0 * gi
#     gk = sum(gh)
#     _ = gk / 4.0
#     gl = 1.0 / 4.0
#     gm = array(broadcast_to(gl, (4,)))
#     gn = gm * gj
#     go = -gn
#     gp = go[0:2:] if len(go.shape)>=1 else go # static slice inputs:[(0,), (2,), None]
#     gq = go[2:4:] if len(go.shape)>=1 else go # static slice inputs:[(2,), (4,), None]
#     gr = dot(gq, gc)
#     gs = dot(gq, fi)
#     gt = array(broadcast_to(0.0, (4,)))
#     gu = concatenate([ gr[:2] , gt]) # dynamic update slice
#     gv = gs[0:1:][0:2:] if len(gs.shape)>=2 else gs # static slice inputs:[(0, 0), (1, 2), None]
#     gw = gs[1:2:][0:2:] if len(gs.shape)>=2 else gs # static slice inputs:[(1, 0), (2, 2), None]
#     gx = sum(gw)
#     gy = gx[0:1:] if len(gx.shape)>=1 else gx # static slice inputs:[(0,), (1,), None]
#     gz = gx[1:2:] if len(gx.shape)>=1 else gx # static slice inputs:[(1,), (2,), None]
#     ha = sum(gz)
#     hb = -ha
#     hc = hb * ft
#     hd = sum(gy)
#     he = hd * fr
#     hf = hc + he
#     hg = sum(gv)
#     hh = hg[0:1:] if len(hg.shape)>=1 else hg # static slice inputs:[(0,), (1,), None]
#     hi = hg[1:2:] if len(hg.shape)>=1 else hg # static slice inputs:[(1,), (2,), None]
#     hj = sum(hi)
#     hk = -hj
#     hl = hk * fo
#     hm = hf + hl
#     hn = sum(hh)
#     ho = -hn
#     hp = ho * fm
#     hq = hm + hp
#     hr = array(broadcast_to(hq, (1,)))
#     hs = array(broadcast_to(0.0, (2,)))
#     ht = concatenate([ hr[:1] , hs]) # dynamic update slice
#     hu = dot(gp, fg)
#     hv = dot(gp, em)
#     hw = array(broadcast_to(0.0, (4,)))
#     hx = concatenate([ hu[:0] , hw]) # dynamic update slice
#     hy = gu + hx
#     hz = hy[0:1:] if len(hy.shape)>=1 else hy # static slice inputs:[(0,), (1,), None]
#     ia = hy[1:3:] if len(hy.shape)>=1 else hy # static slice inputs:[(1,), (3,), None]
#     ib = hy[3:4:] if len(hy.shape)>=1 else hy # static slice inputs:[(3,), (4,), None]
#     ic = sum(ib)
#     ID = array(broadcast_to(0.0, (4,)))
#     ie = add.ad(ID, ei, ic)
#     IF = dot(ia, ee)
#     ig = dot(ia, dk)
#     ih = array(broadcast_to(0.0, (4,)))
#     ii = concatenate([ IF[:1] , ih]) # dynamic update slice
#     ij = ie + ii
#     ik = ig[0:1:][0:2:] if len(ig.shape)>=2 else ig # static slice inputs:[(0, 0), (1, 2), None]
#     il = ig[1:2:][0:2:] if len(ig.shape)>=2 else ig # static slice inputs:[(1, 0), (2, 2), None]
#     im = sum(il)
#     IN = im[0:1:] if len(im.shape)>=1 else im # static slice inputs:[(0,), (1,), None]
#     io = im[1:2:] if len(im.shape)>=1 else im # static slice inputs:[(1,), (2,), None]
#     ip = sum(io)
#     iq = -ip
#     ir = iq * dv
#     IS = sum(IN)
#     it = IS * dt
#     iu = ir + it
#     iv = sum(ik)
#     iw = iv[0:1:] if len(iv.shape)>=1 else iv # static slice inputs:[(0,), (1,), None]
#     ix = iv[1:2:] if len(iv.shape)>=1 else iv # static slice inputs:[(1,), (2,), None]
#     iy = sum(ix)
#     iz = -iy
#     ja = iz * dq
#     jb = iu + ja
#     jc = sum(iw)
#     jd = -jc
#     je = jd * do
#     jf = jb + je
#     jg = array(broadcast_to(jf, (1,)))
#     jh = array(broadcast_to(0.0, (1,)))
#     ji = concatenate([ jg[:0] , jh]) # dynamic update slice
#     jj = sum(hz)
#     jk = array(broadcast_to(jj, (1,)))
#     jl = array(broadcast_to(0.0, (4,)))
#     jm = concatenate([ jk[:0] , jl]) # dynamic update slice
#     jn = ij + jm
#     jo = jn[0:2:] if len(jn.shape)>=1 else jn # static slice inputs:[(0,), (2,), None]
#     jp = jn[2:4:] if len(jn.shape)>=1 else jn # static slice inputs:[(2,), (4,), None]
#     jq = dot(jp, de)
#     jr = dot(jp, ck)
#     js = array(broadcast_to(0.0, (4,)))
#     jt = concatenate([ jq[:2] , js]) # dynamic update slice
#     ju = jr[0:1:][0:2:] if len(jr.shape)>=2 else jr # static slice inputs:[(0, 0), (1, 2), None]
#     jv = jr[1:2:][0:2:] if len(jr.shape)>=2 else jr # static slice inputs:[(1, 0), (2, 2), None]
#     jw = sum(jv)
#     jx = jw[0:1:] if len(jw.shape)>=1 else jw # static slice inputs:[(0,), (1,), None]
#     jy = jw[1:2:] if len(jw.shape)>=1 else jw # static slice inputs:[(1,), (2,), None]
#     jz = sum(jy)
#     ka = -jz
#     kb = ka * cv
#     kc = sum(jx)
#     kd = kc * ct
#     ke = kb + kd
#     kf = sum(ju)
#     kg = kf[0:1:] if len(kf.shape)>=1 else kf # static slice inputs:[(0,), (1,), None]
#     kh = kf[1:2:] if len(kf.shape)>=1 else kf # static slice inputs:[(1,), (2,), None]
#     ki = sum(kh)
#     kj = -ki
#     kk = kj * cq
#     kl = ke + kk
#     km = sum(kg)
#     kn = -km
#     ko = kn * co
#     kp = kl + ko
#     kq = array(broadcast_to(kp, (1,)))
#     kr = array(broadcast_to(0.0, (2,)))
#     ks = concatenate([ kq[:1] , kr]) # dynamic update slice
#     kt = dot(jo, ci)
#     ku = dot(jo, bo)
#     kv = array(broadcast_to(0.0, (4,)))
#     kw = concatenate([ kt[:0] , kv]) # dynamic update slice
#     kx = jt + kw
#     ky = kx[1:3:] if len(kx.shape)>=1 else kx # static slice inputs:[(1,), (3,), None]
#     kz = dot(ky, be)
#     la = kz[0:1:][0:2:] if len(kz.shape)>=2 else kz # static slice inputs:[(0, 0), (1, 2), None]
#     lb = kz[1:2:][0:2:] if len(kz.shape)>=2 else kz # static slice inputs:[(1, 0), (2, 2), None]
#     lc = sum(lb)
#     ld = lc[0:1:] if len(lc.shape)>=1 else lc # static slice inputs:[(0,), (1,), None]
#     le = lc[1:2:] if len(lc.shape)>=1 else lc # static slice inputs:[(1,), (2,), None]
#     lf = sum(le)
#     lg = -lf
#     lh = lg * u
#     li = sum(ld)
#     lj = li * s
#     lk = lh + lj
#     ll = sum(la)
#     lm = ll[0:1:] if len(ll.shape)>=1 else ll # static slice inputs:[(0,), (1,), None]
#     ln = ll[1:2:] if len(ll.shape)>=1 else ll # static slice inputs:[(1,), (2,), None]
#     lo = sum(ln)
#     lp = -lo
#     lq = lp * p
#     lr = lk + lq
#     ls = sum(lm)
#     lt = -ls
#     lu = lt * n
#     lv = lr + lu
#     lw = array(broadcast_to(lv, (1,)))
#     lx = array(broadcast_to(0.0, (1,)))
#     ly = concatenate([ lw[:0] , lx]) # dynamic update slice
#     lz = ku[0:1:][0:2:] if len(ku.shape)>=2 else ku # static slice inputs:[(0, 0), (1, 2), None]
#     ma = ku[1:2:][0:2:] if len(ku.shape)>=2 else ku # static slice inputs:[(1, 0), (2, 2), None]
#     mb = sum(ma)
#     mc = mb[0:1:] if len(mb.shape)>=1 else mb # static slice inputs:[(0,), (1,), None]
#     md = mb[1:2:] if len(mb.shape)>=1 else mb # static slice inputs:[(1,), (2,), None]
#     me = sum(md)
#     mf = -me
#     mg = mf * bz
#     mh = sum(mc)
#     mi = mh * bx
#     mj = mg + mi
#     mk = sum(lz)
#     ml = mk[0:1:] if len(mk.shape)>=1 else mk # static slice inputs:[(0,), (1,), None]
#     mm = mk[1:2:] if len(mk.shape)>=1 else mk # static slice inputs:[(1,), (2,), None]
#     mn = sum(mm)
#     mo = -mn
#     mp = mo * bu
#     mq = mj + mp
#     mr = sum(ml)
#     ms = -mr
#     mt = ms * bs
#     mu = mq + mt
#     mv = array(broadcast_to(mu, (1,)))
#     mw = array(broadcast_to(0.0, (2,)))
#     mx = concatenate([ mv[:0] , mw]) # dynamic update slice
#     my = ks + mx
#     mz = hv[0:1:][0:2:] if len(hv.shape)>=2 else hv # static slice inputs:[(0, 0), (1, 2), None]
#     na = hv[1:2:][0:2:] if len(hv.shape)>=2 else hv # static slice inputs:[(1, 0), (2, 2), None]
#     nb = sum(na)
#     nc = nb[0:1:] if len(nb.shape)>=1 else nb # static slice inputs:[(0,), (1,), None]
#     nd = nb[1:2:] if len(nb.shape)>=1 else nb # static slice inputs:[(1,), (2,), None]
#     ne = sum(nd)
#     nf = -ne
#     ng = nf * ex
#     nh = sum(nc)
#     ni = nh * ev
#     nj = ng + ni
#     nk = sum(mz)
#     nl = nk[0:1:] if len(nk.shape)>=1 else nk # static slice inputs:[(0,), (1,), None]
#     nm = nk[1:2:] if len(nk.shape)>=1 else nk # static slice inputs:[(1,), (2,), None]
#     nn = sum(nm)
#     no = -nn
#     np = no * es
#     nq = nj + np
#     nr = sum(nl)
#     ns = -nr
#     nt = ns * eq
#     nu = nq + nt
#     nv = array(broadcast_to(nu, (1,)))
#     nw = array(broadcast_to(0.0, (2,)))
#     nx = concatenate([ nv[:0] , nw]) # dynamic update slice
#     ny = ht + nx
#     return ny, ji, my, ly

# %% [markdown]
# # MNIST classification

# %% [markdown]
# Read the raw dataset

# %%
from keras.datasets import mnist
import numpy as npo
(train_X, train_y), (test_X, test_y) = mnist.load_data()

# %% [markdown]
# Preprocessing dataset (scaling, reshaping, projection, shuffling...)

# %%
# data processing
train_X=train_X.reshape((60000,28*28))/255.
test_X=test_X.reshape((10000,28*28))/255.

# projection
n_comp=10
from sklearn.decomposition import PCA
proj = PCA(n_components = n_comp)
train_X = proj.fit_transform(train_X)
test_X=proj.transform(test_X)

# label processing into one-hot vector
train_y2=npo.zeros((60000,n_comp),dtype=float)
test_y2=npo.zeros((10000,n_comp), dtype=float)
for i,v in enumerate(train_y):
    train_y2[i][v]=1.

for i,v in enumerate(test_y):
    test_y2[i][v]=1.

# shuffling
ids=npo.array(range(len(train_X)))
npo.random.shuffle(ids)
train_X=train_X[ids]
train_y2=train_y2[ids]

ids=npo.array(range(len(test_X)))
npo.random.shuffle(ids)
test_X=test_X[ids]
test_y2=test_y2[ids]

# Dimension check
print(train_X.shape)
print(train_y2.shape)
print(test_X.shape)
print(test_y2.shape)
# Out:
# (60000, 10)
# (60000, 10)
# (10000, 10)
# (10000, 10)

# %% [markdown]
# Definition of the ONN (forward)

# %%
# Place holders
dumb_X=np.zeros((n_comp,))
dumb_Y=np.zeros((n_comp,))

# Init weights
nb_mzis=spec_mesh(10, 5)
W=[]
for n in nb_mzis:
    W.append(glorot_init(n))

# compilation of the onn
@jax.jit
def onn10(X, W):
    # architecture spec. cannot be given as input of onn10 otherwise it cannot be compilable
    nb_mzis=spec_mesh(10, 5) #10 columns of 5 or 4 MZIs
    return onn(X, nb_mzis, W)
circuit=onn10

# %% [markdown]
# Backward definition

# %%
# Create the circuit with metric
def circuit_to_opt(*args):
    y_pred=circuit(*(args[0], args[2])) #0:X, 2:W
    y_expected=args[1] #1:Y
    loss=np.mean((y_expected-y_pred)**2)
    return loss

deriv_circuit_to_opt=jax.grad(circuit_to_opt, argnums=(-1,))

# %% [markdown]
# Training loop

# %%
n_eval=1000
n_train=60000
eval_every=10000
for ds_id in range(0, n_train): # for each data sample
    # input the photonic circuit
    circuit_to_opt_args=(train_X[ds_id], train_y2[ds_id], W)

    # backward phase
    dW=deriv_circuit_to_opt(*circuit_to_opt_args)[0]

    # Update using the gradient information
    if isinstance(dW, list): # dW is always a sequence of arrays
        for i, dWi in enumerate(dW):
            circuit_to_opt_args[trainable_arg_id][i] = circuit_to_opt_args[trainable_arg_id][i] - lr * dWi
    else:
        circuit_to_opt_args[trainable_arg_id] = circuit_to_opt_args[trainable_arg_id] - lr * dW

    # EVALUATION
    if ds_id%eval_every==0 and ds_id>0:
        is_ok=0
        for ds_id in range(0, n_eval):
            y_pred=circuit(*(test_X[ds_id], W))
            is_ok+=np.argmax(y_pred)==np.argmax(test_y2[ds_id])
        print(f"accuracy:{float(is_ok)/n_eval}")
        lr/=2.
# Out:
# accuracy:0.565
# accuracy:0.604
# accuracy:0.621
# accuracy:0.624
# accuracy:0.626
